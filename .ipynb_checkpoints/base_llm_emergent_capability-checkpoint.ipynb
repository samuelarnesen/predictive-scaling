# %% [markdown]
# <a href="https://colab.research.google.com/github/ryoungj/ObsScaling/blob/main/base_llm_emergent_capability.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Emergent Capability Analysis
#
# This notebook shows how to apply observational scaling laws to predict the "emergent" capabilities, corresponding to the Sec 4.1 of the paper.

# %% [markdown]
# ## Preparation

# %% [markdown]
# Colab specific setup: uncomment the following lines in colab

# %%
# ! git clone https://github.com/ryoungj/ObsScaling
# %cd ObsScaling
#pip install -r requirements.txt

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import json
import re
import copy

from utils import *

# %%
# %load_ext autoreload 
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load Eval Data

# %% [markdown]
# Load benchmark eval results for base LLMs

# %%
base_llm_benchmark_eval = load_base_llm_benchmark_eval()

# %% [markdown]
# Load emergent capability eval results for base LLMs

# %%
eval_result_path = "./eval_results/base_llm_emergent_capability_eval.csv"
emerg_cap_eval = pd.read_csv(eval_result_path)

# %% [markdown]
# Merge eval results

# %%
base_llm_eval_with_emg_eval = pd.merge(base_llm_benchmark_eval, emerg_cap_eval, on='Model')

# %% [markdown]
# ## Scaling Analysis

# %% [markdown]
# Specify downstream metrics for analysis

# %%
# Arithmetic tasks
EMERG_CAP_ARITHMETIC_TASK_MAP = {
    'arithmetic_3ds_2_acc': "3-Digit Substraction",
    'arithmetic_2dm_2_acc': "2-Digit Multiplication",
    ## additional tasks
    # 'arithmetic_3da_2_acc': "3-Digit Addiiton",
    # 'arithmetic_2da_2_acc': "2-Digit Addiiton",
}

EMERG_CAP_ARITHMETIC_TASKS = list(EMERG_CAP_ARITHMETIC_TASK_MAP.keys())

# Nonarithmetic tasks
EMERG_CAP_NONARITHMETIC_TASK_MAP = {
    'word_unscrambling_2_exact_match': "Word Unscramble",
    'parsinlu_qa_2_acc': "Persian QA",
    ## additional tasks
    # 'ipa_transliterate_2_bleu': "IPA transliterate",
}

EMERG_CAP_NONARITHMETIC_TASKS = list(EMERG_CAP_NONARITHMETIC_TASK_MAP.keys())

EMERG_CAP_TASK_MAP = {**EMERG_CAP_ARITHMETIC_TASK_MAP, **EMERG_CAP_NONARITHMETIC_TASK_MAP}
EMERG_CAP_TASKS = EMERG_CAP_NONARITHMETIC_TASKS + EMERG_CAP_ARITHMETIC_TASKS

# %% [markdown]
# Setup specific arguments

# %%
EMERG_CAP_DEFAULT_SETUP_KWARGS = {
    # Metric normalization
    "y_metric_process_funcs": "minmax_norm",

    # Group markers by model family
    "df_groupby": 'Model Family',  
    
    # Regression: ordinary least squares
    "reg_method": "robust",  
    "reg_kwargs": {"delta": 1.0},   # huber loss with delta=1.0 for normalized target within [0, 1] reduces to OLS
}

# %%
testing = True
EMERG_CAP_EVAL_SETUP_SPECIFIC_KWARGS = {}    

for e in EMERG_CAP_TASKS:
    EMERG_CAP_EVAL_SETUP_SPECIFIC_KWARGS[e] = {}

    # Metric range
    ## Minimum: the metric value of random guess
    if 'parsinlu_qa' in e:
        random_val = 0.25
    else:
        random_val = 0.0

    ## Maximum: the metric value of perfect prediction
    if "bleu" in e:
        max_val = 100.0
    else:
        max_val = 1.0
    
    EMERG_CAP_EVAL_SETUP_SPECIFIC_KWARGS[e]['y_metric_range'] = (random_val, max_val)

    # PCA & cutoff arguments
    if 'arithmetic' in e:  # Arithmetic tasks
        # Exclude the GSM8K metrics to avoid making the prediction task trivial
        EMERG_CAP_EVAL_SETUP_SPECIFIC_KWARGS[e].update(NONGSM_PCA_PREPROCESS_KWARGS)
        # Set a lower cutoff threshold to make the task more challenging
        EMERG_CAP_EVAL_SETUP_SPECIFIC_KWARGS[e].update({
            "split_method": "cutoff_by_FLOPs (1E21)" if not testing else "model_family_cutoff_by_FLOPs (1E21)",
            "cutoff_threshold": 22,
            "plot_adjust_kwargs": {"ylim": [-0.03, 1.13]}
        })
    else:  # Nonarithmetic tasks, use default setup
        EMERG_CAP_EVAL_SETUP_SPECIFIC_KWARGS[e].update(DEFAULT_PCA_PREPROCESS_KWARGS)
        EMERG_CAP_EVAL_SETUP_SPECIFIC_KWARGS[e].update({
            "split_method": "cutoff_by_FLOPs (1E21)" if not testing else "model_family_cutoff_by_FLOPs (1E21)",
            "cutoff_threshold": 84,
        })

# %%
PLOT_X_METRICS_LIST = [MODEL_SIZE_METRIC, TRAINING_FLOPS_METRIC, PC_METRIC_NUM_3]

# %% [markdown]
# #### Scaling Predictions

# %% [markdown]
# Compare the scaling predictions with observation scaling laws (PCs) and with compute scaling laws (model size or training FLOPs)

# %%
for x_metrics in PLOT_X_METRICS_LIST[-1:]:   
    fig = plot_multi_scaling_predictions(                        
        base_llm_eval_with_emg_eval, EMERG_CAP_TASKS, [x_metrics], 
        EMERG_CAP_DEFAULT_SETUP_KWARGS, y_metric_specific_kwargs=EMERG_CAP_EVAL_SETUP_SPECIFIC_KWARGS, 
        filter_model_family=EVAL_BASE_MODEL_WITH_FLOPS_FAMILIES, ymetric2title_map=EMERG_CAP_TASK_MAP,
        plot_legend=True, legend_nrow=2,
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[163], line 2
#       1 for x_metrics in PLOT_X_METRICS_LIST:
# ----> 2     fig = plot_multi_scaling_predictions(
#       3         base_llm_eval_with_emg_eval, EMERG_CAP_TASKS, [x_metrics],
#       4         EMERG_CAP_DEFAULT_SETUP_KWARGS, y_metric_specific_kwargs=EMERG_CAP_EVAL_SETUP_SPECIFIC_KWARGS,
#       5         filter_model_family=EVAL_BASE_MODEL_WITH_FLOPS_FAMILIES, ymetric2title_map=EMERG_CAP_TASK_MAP,
#       6         plot_legend=True, legend_nrow=2,
#       7     )
#
# File ~/nyu/ObsScaling/utils/plot.py:559, in plot_multi_scaling_predictions(eval_df, y_metric_list, x_metrics_list, analysis_setup_kwargs, y_metric_specific_kwargs, filter_model_family, plot_legend, legend_nrow, legend_ncol, legend_font_size, transpose, add_dummy_labels, figsize, ymetric2title_map)
#     556     additional_kwargs.update({"transform_x_to_equiv_scale": True})
#     558 # Plot the scaling curves for the current setup
# --> 559 _, _, _, annot_info = plot_scaling_predictions(
#     560     eval_df, x_metrics, y_metric_name,
#     561     **analysis_setup_kwargs,
#     562     **additional_kwargs,
#     563     **specific_kwargs,
#     564 )
#     566 # Rearrange the title and labels
#     567 for label, handle in zip(annot_info["legend_labels"], annot_info["legend_handles"]):
#
# File ~/nyu/ObsScaling/utils/plot.py:197, in plot_scaling_predictions(df, x_metrics, y_metric, x_metrics_process_funcs, y_metric_process_funcs, y_metric_range, apply_imputation, imputation_metrics, imputation_kwargs, apply_pca, pca_metrics, pca_kwargs, nonlinearity, reg_method, reg_kwargs, df_filter, df_filter_by_kvs, df_groupby, split_method, test_limit, cutoff_threshold, heldout_filter, scale_measure_key, transform_x_to_equiv_scale, ref_model_family, plot_logits, stylize_data, stylize_model_family, stylize_by_hue, default_style_kwargs, plot_xrange, plot_scatter, plot_test_scatter, line_kwargs, plot_legend, annot_details, grace_range_ratios, display_reg_metrics, plot_adjust_kwargs, legend_ncol, compute_metrics_only)
#     194 all_df = pd.concat(all_dfs)
#     196 # Fit a multivariate regression model
# --> 197 fit_results = fit_multivariate_regression_model(
#     198     train_df, processed_x_metric_names, processed_y_metric_name,
#     199     nonlinearity=nonlinearity,
#     200     reg_method=reg_method, reg_kwargs=reg_kwargs
#     201 )
#     203 if True:
#     204     fit_results_2 = fit_multivariate_regression_model(
#     205         train_df, ['FLOPs (1E21)'], processed_x_metric_names,
#     206         nonlinearity=nonlinearity,
#     207         reg_method=reg_method, reg_kwargs=reg_kwargs
#     208     )
#
# File ~/nyu/ObsScaling/utils/data.py:591, in fit_multivariate_regression_model(train_df, x_metric_names, y_metric_name, nonlinearity, sigmoid_param_range_width, sigmoid_param_fix_height, reg_method, reg_kwargs)
#     588     delta = reg_kwargs.get("delta", 0.1)
#     589     method = "L-BFGS-B" if bounds is not None else "BFGS"
# --> 591     result = minimize(lambda p: huber_objective_function(p, delta), p0, method=method, bounds=bounds)
#     592     popt = result.x
#     594 if add_nonlinear_params:
#
# File ~/nyu/scratch/scratch-env/lib/python3.10/site-packages/scipy/optimize/_minimize.py:705, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     703     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     704 elif meth == 'bfgs':
# --> 705     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     706 elif meth == 'newton-cg':
#     707     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     708                              **options)
#
# File ~/nyu/scratch/scratch-env/lib/python3.10/site-packages/scipy/optimize/_optimize.py:1419, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1416 if maxiter is None:
#    1417     maxiter = len(x0) * 200
# -> 1419 sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1420                               finite_diff_rel_step=finite_diff_rel_step)
#    1422 f = sf.fun
#    1423 myfprime = sf.grad
#
# File ~/nyu/scratch/scratch-env/lib/python3.10/site-packages/scipy/optimize/_optimize.py:383, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     379     bounds = (-np.inf, np.inf)
#     381 # ScalarFunction caches. Reuse of fun(x) during grad
#     382 # calculation reduces overall function evaluations.
# --> 383 sf = ScalarFunction(fun, x0, args, grad, hess,
#     384                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     386 return sf
#
# File ~/nyu/scratch/scratch-env/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:158, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     155     self.f = fun_wrapped(self.x)
#     157 self._update_fun_impl = update_fun
# --> 158 self._update_fun()
#     160 # Gradient evaluation
#     161 if callable(grad):
#
# File ~/nyu/scratch/scratch-env/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~/nyu/scratch/scratch-env/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~/nyu/scratch/scratch-env/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/nyu/ObsScaling/utils/data.py:591, in fit_multivariate_regression_model.<locals>.<lambda>(p)
#     588     delta = reg_kwargs.get("delta", 0.1)
#     589     method = "L-BFGS-B" if bounds is not None else "BFGS"
# --> 591     result = minimize(lambda p: huber_objective_function(p, delta), p0, method=method, bounds=bounds)
#     592     popt = result.x
#     594 if add_nonlinear_params:
#
# File ~/nyu/ObsScaling/utils/data.py:586, in fit_multivariate_regression_model.<locals>.huber_objective_function(p, delta)
#     584 def huber_objective_function(p, delta):
#     585     y_pred = _func(X_train.values, *p)
# --> 586     return huber_loss(y_train.values, y_pred, delta).sum()
#
# File ~/nyu/ObsScaling/utils/data.py:577, in fit_multivariate_regression_model.<locals>.huber_loss(y_true, y_pred, delta)
#     576 def huber_loss(y_true, y_pred, delta):
# --> 577     residual = y_pred - y_true
#     578     condition = np.abs(residual) <= delta
#     580     squared_loss = 0.5 * residual ** 2
#
# ValueError: operands could not be broadcast together with shapes (47,3) (47,)

# %% [markdown]
# #### Robustness Analysis

# %% [markdown]
# The effect of PCs: compare the scaling predictions using different number of PCs and with training FLOPs as baseline

# %%
DIFF_PC_NUM_PLOT_X_METRICS_LIST = [TRAINING_FLOPS_METRIC, PC_METRIC_NUM_1, PC_METRIC_NUM_2, PC_METRIC_NUM_3, PC_METRIC_NUM_4]

for y_metric in EMERG_CAP_TASKS:
    fig = plot_multi_scaling_predictions(
        base_llm_eval_with_emg_eval, [y_metric], DIFF_PC_NUM_PLOT_X_METRICS_LIST, 
        EMERG_CAP_DEFAULT_SETUP_KWARGS, y_metric_specific_kwargs=EMERG_CAP_EVAL_SETUP_SPECIFIC_KWARGS, 
        filter_model_family=EVAL_BASE_MODEL_WITH_FLOPS_FAMILIES, ymetric2title_map=EMERG_CAP_TASK_MAP,
        plot_legend=True, legend_nrow=2, transpose=True
    )

# %% [markdown]
# The effect of cutoff: vary the metric cutoff, plot the test MSE, and compute the mean test MSE (area under the error curve)

# %%
# vary the Y metric (downstream performance) cutoff to change test size from 0.6 to 0.05, simulating a weak to strong generalization setup
split_limit_ranges = np.linspace(0.6, 0.05, 30)
rank_metric_name = "y_metric"

regress_metrics_to_plot = ['mse_test']

# remove default cutoff setup args
setup_specific_kwargs = copy.deepcopy(EMERG_CAP_EVAL_SETUP_SPECIFIC_KWARGS)
for e, kwargs in setup_specific_kwargs.items():
    del kwargs["split_method"]
    del kwargs["cutoff_threshold"]


fig = plot_reg_metric_curves(
    base_llm_eval_with_emg_eval,
    ALL_X_METRICS_LIST,
    EMERG_CAP_TASKS,
    rank_metric_name,
    split_limit_ranges,
    regress_metrics_to_plot,
    EMERG_CAP_DEFAULT_SETUP_KWARGS,
    filter_model_family=EVAL_BASE_MODEL_WITH_FLOPS_FAMILIES,
    y_metric_specific_kwargs=setup_specific_kwargs,
    ymetric2title_map=EMERG_CAP_TASK_MAP,
)
# Out:
# 4it [07:45, 116.29s/it]
